# %%
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
# Out:
# C:\Users\Chankoo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv("https://stats.idre.ucla.edu/stat/data/binary.csv")
df.head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %%
df.describe() # 빈도수, 평균, 분산, 최솟값, 최댓값, 1/4분위수, 중위값, 1/4분위수를 나타냄
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0644c712a6f4> in <module>()
# ----> 1 df.describe() # 빈도수, 평균, 분산, 최솟값, 최댓값, 1/4분위수, 중위값, 1/4분위수를 나타냄
#
# NameError: name 'df' is not defined

# %%
df.std() # 분산 출력
# Out:
# admit      0.466087
# gre      115.516536
# gpa        0.380567
# rank       0.944460
# dtype: float64

# %%
pd.crosstab(df['admit'], df['rank'], rownames=['admit'])
# Out:
# rank    1   2   3   4
# admit
# 0      28  97  93  55
# 1      33  54  28  12

# %%
df.hist()
pl.show() #그래프로 요약

# %%
######실습!!!#####
#위 데이터를 토대로 로지스틱 회귀분석 실시 후 결과해석을 하고, 오즈비를 계산해보세요!
#hint-> 밑에 표와 같이 범주형변수 rank를 더미변수화해야합니다.
# Out:
#    rank_1  rank_2  rank_3  rank_4
# 0       0       0       1       0
# 1       0       0       1       0
# 2       1       0       0       0
# 3       0       0       0       1
# 4       0       0       0       1

# %%
dummy_ranks =

# %%
# Out:
#      admit  gre   gpa  rank
# 0        0  380  3.61     3
# 1        1  660  3.67     3
# 2        1  800  4.00     1
# 3        1  640  3.19     4
# 4        0  520  2.93     4
# 5        1  760  3.00     2
# 6        1  560  2.98     1
# 7        0  400  3.08     2
# 8        1  540  3.39     3
# 9        0  700  3.92     2
# 10       0  800  4.00     4
# 11       0  440  3.22     1
# 12       1  760  4.00     1
# 13       0  700  3.08     2
# 14       1  700  4.00     1
# 15       0  480  3.44     3
# 16       0  780  3.87     4
# 17       0  360  2.56     3
# 18       0  800  3.75     2
# 19       1  540  3.81     1
# 20       0  500  3.17     3
# 21       1  660  3.63     2
# 22       0  600  2.82     4
# 23       0  680  3.19     4
# 24       1  760  3.35     2
# 25       1  800  3.66     1
# 26       1  620  3.61     1
# 27       1  520  3.74     4
# 28       1  780  3.22     2
# 29       0  520  3.29     1
# ..     ...  ...   ...   ...
# 370      1  540  3.77     2
# 371      1  680  3.76     3
# 372      1  680  2.42     1
# 373      1  620  3.37     1
# 374      0  560  3.78     2
# 375      0  560  3.49     4
# 376      0  620  3.63     2
# 377      1  800  4.00     2
# 378      0  640  3.12     3
# 379      0  540  2.70     2
# 380      0  700  3.65     2
# 381      1  540  3.49     2
# 382      0  540  3.51     2
# 383      0  660  4.00     1
# 384      1  480  2.62     2
# 385      0  420  3.02     1
# 386      1  740  3.86     2
# 387      0  580  3.36     2
# 388      0  640  3.17     2
# 389      0  640  3.51     2
# 390      1  800  3.05     2
# 391      1  660  3.88     2
# 392      1  600  3.38     3
# 393      1  620  3.75     2
# 394      1  460  3.99     3
# 395      0  620  4.00     2
# 396      0  560  3.04     3
# 397      0  460  2.63     2
# 398      0  700  3.65     2
# 399      0  600  3.89     3
#
# [400 rows x 4 columns]
